# %% [markdown]
# Library

# %%
import PIL.Image as image
import matplotlib.pyplot as plt

# %% [markdown]
# Open Image

# %%
rgb_img=image.open('VU-Logo.png')
plt.imshow(rgb_img)
plt.show()

# %% [markdown]
# Image Mode

# %%
image_mode=rgb_img.mode
print(image_mode)
# Out:
# RGBA

# %% [markdown]
# Image Size

# %%
print(rgb_img.size)
# Out:
# (120, 200)

# %% [markdown]
# Image Resolution

# %%
width,height=rgb_img.size
print(f'Resolition is: {width}px x {height}px')
# Out:
# Resolition is: 120px x 200px

# %% [markdown]
# Convert into Grayscale

# %%
gray_img=rgb_img.convert('L')
plt.imshow(gray_img, cmap='gray')
plt.show()

# %%
gray_img.save('VU-Logo-gray.png')

# %% [markdown]
# Title: color space conversion
# Lab Report
# Submit next lab
